# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from keras.applications import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input
from keras.models import Model

# Step 1: Loading Labels

label_file_path = "/content/drive/MyDrive/Oil_GVF_prediction_CNN_models/oil_water_label.csv"
labels_df = pd.read_csv(label_file_path)

# Step 2: Feature Extraction

# Load pre-trained ResNet50 model
base_model = ResNet50(weights='imagenet', include_top=False)

# Remove the last layer of ResNet50 and use the output of the second last layer as features
model = Model(inputs=base_model.input, outputs=base_model.layers[-2].output)

# Define a function to extract features from images
def extract_features(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    features = model.predict(x)
    return features.flatten()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
# Step 3: Data Labeling

# Merge labels with image paths
data = []
for index, row in labels_df.iterrows():
    experiment_name = row['Experiment Number']
    bg_flow = row['Background Flow (m3/h)']
    WaterCut = row['water cut (%)']
    folder_path = os.path.join("/content/drive/MyDrive/Oil_GVF_prediction_CNN_models/stft_oil_water", experiment_name)
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        features = extract_features(img_path)
        data.append([experiment_name, bg_flow, WaterCut, img_path] + features.tolist())
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 1s 766ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 1s 701ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 1s 512ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 821ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 1s 515ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 1s 511ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 199ms/step

# %%
# Create DataFrame
columns = ['Experiment Number', 'Background Flow', 'WaterCut', 'Image Path'] + [f'feature_{i}' for i in range(100352)]
df = pd.DataFrame(data, columns=columns)

# %%
df.head()
# Out:
#   Experiment Number  Background Flow  WaterCut  \
# 0       be22007_000                5         0
# 1       be22007_000                5         0
# 2       be22007_000                5         0
# 3       be22007_000                5         0
# 4       be22007_000                5         0
#
#                                           Image Path  feature_0  feature_1  \
# 0  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.704112  -2.407605
# 1  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -2.007420  -1.857557
# 2  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.796762  -1.993771
# 3  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.737471  -1.726743
# 4  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.770987  -1.801598
#
#    feature_2  feature_3  feature_4  feature_5  ...  feature_100342  \
# 0  -1.657305  -0.571712  -3.032980  -0.431641  ...       -0.314348
# 1  -1.782360   0.409304  -2.429142  -0.547343  ...        1.781727
# 2  -1.962892   2.325828  -2.645463   1.255233  ...        3.950834
# 3  -2.082922   2.394396  -1.945735   2.245593  ...        1.907041
# 4  -1.730463   0.996756  -1.956371  -0.065137  ...        1.321373
#
#    feature_100343  feature_100344  feature_100345  feature_100346  \
# 0       -5.165875       -3.773847       -2.038293        1.057652
# 1       -4.862500       -2.713357       -1.649416       -0.065765
# 2       -4.678708       -3.662419       -1.379766        0.623397
# 3       -4.231230       -3.241199       -1.708435        0.100133
# 4       -4.036424       -2.983791       -1.512003        0.127408
#
#    feature_100347  feature_100348  feature_100349  feature_100350  \
# 0       -3.201055        0.043826       -0.798262        1.928447
# 1       -3.518343       -0.412726       -1.092676        0.242206
# 2       -3.291280       -0.203477       -1.210324        0.867371
# 3       -3.730419        0.004276       -1.048185        0.479222
# 4       -3.245956       -1.111794       -1.402104        1.085548
#
#    feature_100351
# 0        4.342771
# 1        3.830615
# 2        6.686132
# 3        3.981187
# 4        4.464328
#
# [5 rows x 100356 columns]

# %%
df
# Out:
#     Experiment Number  Background Flow  WaterCut  \
# 0         be22007_000                5         0
# 1         be22007_000                5         0
# 2         be22007_000                5         0
# 3         be22007_000                5         0
# 4         be22007_000                5         0
# ..                ...              ...       ...
# 126       be22008_006               30        40
# 127       be22008_006               30        40
# 128       be22008_007               30        60
# 129       be22008_007               30        60
# 130       be22008_007               30        60
#
#                                             Image Path  feature_0  feature_1  \
# 0    /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.704112  -2.407605
# 1    /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -2.007420  -1.857557
# 2    /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.796762  -1.993771
# 3    /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.737471  -1.726743
# 4    /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.770987  -1.801598
# ..                                                 ...        ...        ...
# 126  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -0.927347  -2.351417
# 127  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.343227  -2.112404
# 128  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.055092  -1.794115
# 129  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -1.001012  -2.081178
# 130  /content/drive/MyDrive/Oil_GVF_prediction_CNN_...  -0.945729  -2.256156
#
#      feature_2  feature_3  feature_4  feature_5  ...  feature_100342  \
# 0    -1.657305  -0.571712  -3.032980  -0.431641  ...       -0.314348
# 1    -1.782360   0.409304  -2.429142  -0.547343  ...        1.781727
# 2    -1.962892   2.325828  -2.645463   1.255233  ...        3.950834
# 3    -2.082922   2.394396  -1.945735   2.245593  ...        1.907041
# 4    -1.730463   0.996756  -1.956371  -0.065137  ...        1.321373
# ..         ...        ...        ...        ...  ...             ...
# 126  -0.766959  -1.819230  -1.865539  -2.171415  ...       -1.037999
# 127  -0.599805  -2.109538  -2.254396  -1.685828  ...        0.393618
# 128  -1.556356  -1.918940  -2.319692  -2.037765  ...        0.952077
# 129  -1.062793  -1.344202  -1.550028  -1.977974  ...        0.200619
# 130   0.143708  -2.162992  -1.159534  -2.141494  ...       -1.676282
#
#      feature_100343  feature_100344  feature_100345  feature_100346  \
# 0         -5.165875       -3.773847       -2.038293        1.057652
# 1         -4.862500       -2.713357       -1.649416       -0.065765
# 2         -4.678708       -3.662419       -1.379766        0.623397
# 3         -4.231230       -3.241199       -1.708435        0.100133
# 4         -4.036424       -2.983791       -1.512003        0.127408
# ..              ...             ...             ...             ...
# 126       -5.150139       -3.148723       -1.169032        2.118442
# 127       -5.420557       -3.386472       -1.240297        0.188536
# 128       -4.305146       -1.979046       -1.612211        1.118734
# 129       -4.406155       -2.811883       -1.310474        2.506424
# 130       -4.747489       -3.233483       -1.402071        1.177595
#
#      feature_100347  feature_100348  feature_100349  feature_100350  \
# 0         -3.201055        0.043826       -0.798262        1.928447
# 1         -3.518343       -0.412726       -1.092676        0.242206
# 2         -3.291280       -0.203477       -1.210324        0.867371
# 3         -3.730419        0.004276       -1.048185        0.479222
# 4         -3.245956       -1.111794       -1.402104        1.085548
# ..              ...             ...             ...             ...
# 126       -2.985925       -0.686486       -1.770743        2.296762
# 127       -3.319450       -0.580546       -2.002609        0.849668
# 128       -4.054163       -1.078200       -1.836268        2.580209
# 129       -3.725084       -0.972366       -1.288592        1.891505
# 130       -3.369657       -1.383520       -1.858492       -0.312780
#
#      feature_100351
# 0          4.342771
# 1          3.830615
# 2          6.686132
# 3          3.981187
# 4          4.464328
# ..              ...
# 126        3.138298
# 127        0.366454
# 128        2.077742
# 129        4.534843
# 130        4.123344
#
# [131 rows x 100356 columns]

# %%
# Step 4: Model Training

# Separate features and labels
X = df.iloc[:, 4:]  # Features
y_bg_flow = df['Background Flow']  # Background Flow
y_WaterCut = df['WaterCut']  # Water cut

# %%
# Split data into train and test sets
X_train, X_test, y_train_bg_flow, y_test_bg_flow, y_train_WaterCut, y_test_WaterCut = train_test_split(X, y_bg_flow, y_WaterCut, test_size=0.2, random_state=42)

# %%
# Step 5: Model Selection and Training

# Random Forest Regressor for Background Flow
rf_bg_flow = RandomForestRegressor(n_estimators=100, random_state=42)
rf_bg_flow.fit(X_train, y_train_bg_flow)

# Random Forest Regressor for GVF
rf_WaterCut = RandomForestRegressor(n_estimators=100, random_state=42)
rf_WaterCut.fit(X_train, y_train_WaterCut)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Step 6: Model Evaluation

# Predictions for Background Flow
y_pred_bg_flow = rf_bg_flow.predict(X_test)
mae_bg_flow = mean_absolute_error(y_test_bg_flow, y_pred_bg_flow)
print("MAE for Background Flow:", mae_bg_flow)

# Predictions for GVF
y_pred_WaterCut = rf_WaterCut.predict(X_test)
mae_WaterCut = mean_absolute_error(y_test_WaterCut, y_pred_WaterCut)
print("MAE for Water CUT:", mae_WaterCut)
# Out:
# MAE for Background Flow: 5.212962962962963
# MAE for Water CUT: 15.420740740740738

# %%
import math
# Function to predict Background Flow and GVF for a single image
def predict_values_for_image(img_path):
    # Extract features from the image
    features = extract_features(img_path)

    # Reshape the features to match the input shape expected by the model
    features = features.reshape(1, -1)

    # Predict Background Flow and GVF values
    bg_flow_prediction = rf_bg_flow.predict(features)
    WaterCut_prediction = rf_WaterCut.predict(features)

    return bg_flow_prediction[0], WaterCut_prediction[0]

# %%
new_image_path = "/content/drive/MyDrive/Oil_GVF_prediction_CNN_models/stft_oil_water/be22007_008/21_02_2022_12_24_18_00_hdf5.png"
bg_flow_pred, WaterCut_pred = predict_values_for_image(new_image_path)

print("Predicted Background Flow:", math.ceil(bg_flow_pred))
print("Predicted GVF:", math.ceil(WaterCut_pred))
# Out:
# 1/1 [==============================] - 0s 189ms/step
# Predicted Background Flow: 8
# Predicted GVF: 67
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
